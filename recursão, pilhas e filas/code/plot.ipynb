# %%
import matplotlib.pyplot as plt
import numpy as np

rec_data = np.array([0.000001, 0.000001, 0.000001, 0.000001, 0.000001, 0.000002, 0.000005, 0.000009, 0.000017, 0.000035, 0.000068, 0.000137, 0.000274, 0.000547, 0.001095, 0.002199, 0.004399, 0.008882, 0.017992, 0.035862, 0.071409, 0.142656, 0.284559, 0.569963, 1.166755, 2.338083, 4.667496, 9.878358, 18.588232, 40.067149,])
iter_data = np.array([0.000001, 0.000001, 0.000001, 0.000001, 0.000001, 0.000002, 0.000004, 0.000008, 0.000013, 0.000027, 0.000053, 0.000106, 0.000206, 0.000417, 0.000826, 0.001652, 0.003303, 0.007232, 0.013649, 0.026664, 0.053073, 0.105955, 0.212198, 0.423424, 0.855295, 1.684427, 3.363907, 6.717645, 13.467542, 27.024288,])

print(rec_data.shape)

x_axis = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x_axis, rec_data, color='tab:blue')
ax.plot(x_axis, iter_data, color='tab:orange')

# plt.yscale('log')
plt.xscale('log')

ax.set_title('line plot with data points')
plt.grid()

plt.show()
# Out:
# (30,)

# %%
diff = (rec_data - iter_data) / rec_data

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x_axis, diff, color='tab:blue')

plt.xscale('log')
plt.ylim([0, 1.1])
plt.xlim(left=0)

ax.set_title('line plot with data points')
plt.grid()

plt.show()
# Out:
# /tmp/ipykernel_43546/422081360.py:9: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim(left=0)
